# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor

# %%
import os
os.listdir('input')
# Out:
# ['fulfilment_center_info.csv',
#  'meal_info.csv',
#  'sample_submission_hSlSoT6.csv',
#  'test_processed.csv',
#  'test_QoiMO9B.csv',
#  'train.csv',
#  'train_processed.csv']

# %%
df_train = pd.read_csv('input/train_processed.csv')
df_submit = pd.read_csv('input/test_processed.csv')

# %%
#Preparing dtaframe for catboost
df_tmp = df_train.drop(['Unnamed: 0','id','center_id', 'meal_id',
       'city_code', 'region_code', 'city_region',
       'center_type', 'category', 'cuisine','num_orders_log1p',
        'city_code', 'region_code'], axis=1)

# %%
df_tmp['Quarter']=(df_tmp['week']/13).astype('int64')
df_tmp['Quarter'] = df_tmp['Quarter'].map({0:'Q1',
                         1:'Q2',
                         2:'Q3',
                         3:'Q4',
                         4:'Q1',
                         5:'Q2',
                         6:'Q3',
                         7:'Q4',
                         8:'Q1',
                         9:'Q2',
                         10:'Q3',
                         11:'Q4'})

df_tmp['Year']=(df_tmp['week']/52).astype('int64')
df_tmp['Year'] = df_tmp['Year'].map({0:'Y1',
                         1:'Y2',
                         2:'Y3',
                         3:'Y4',
                         4:'Y5'})

# %%
cat_cols_catboost = ['week','meal_id_encoded',
                     'center_id_encoded',
                     'emailer_for_promotion',
                     'homepage_featured',
                     'city_region_encoded',
                     'center_type_encoded',
                     'category_encoded',
                     'cuisine_encoded',
                    'Quarter',
                    'Year'
                    ]

# %%
df_tmp.columns
# Out:
# Index(['week', 'checkout_price', 'base_price', 'emailer_for_promotion',
#        'homepage_featured', 'num_orders', 'op_area', 'discount',
#        'rate_of_discount', 'week_sin', 'week_cos', 'center_id_encoded',
#        'meal_id_encoded', 'city_code_encoded', 'region_code_encoded',
#        'city_region_encoded', 'center_type_encoded', 'category_encoded',
#        'cuisine_encoded', 'Quarter', 'Year'],
#       dtype='object')

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df_tmp.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_tmp[top_corr_features].corr(),annot=True)

# %%
df_trn = df_tmp[df_tmp['week'] < 135]
df_tst = df_tmp[df_tmp['week'] > 134]

# %%
y_train = df_trn['num_orders']
X_train = df_trn.drop('num_orders', axis=1)

y_test = df_tst['num_orders']
X_test = df_tst.drop('num_orders', axis=1)

# %%
#y = df_tmp['num_orders']
#X = df_tmp.drop('num_orders', axis=1)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.03, 
                                                    shuffle=False)

# %%
model = CatBoostRegressor(cat_features = cat_cols_catboost, ignored_features = ['week_cos','discount','base_price'], 'depth': 8, 'iterations': 1000, 'l2_leaf_reg': 3, 'learning_rate': 0.1, early_stopping_rounds=500)

# %%
#grid = {'learning_rate': [0.01, 0.1, 1], 'depth':[4,6,8]}

# %%
#grid_search_resut = model.grid_search(grid, X=X_train, y=y_train, plot=True)

# %%
#params = grid_search_resut.get('params')

# %%
model.fit(X, y, cat_features = cat_cols_catboost)
# Out:
# Learning rate set to 0.116088
# 0:	learn: 369.2123842	total: 913ms	remaining: 15m 12s
# 1:	learn: 348.7046991	total: 1.57s	remaining: 13m 4s
# 2:	learn: 330.4165810	total: 2.37s	remaining: 13m 6s
# 3:	learn: 314.8188844	total: 2.86s	remaining: 11m 53s
# 141:	learn: 166.8341592	total: 1m 46s	remaining: 10m 42s
# 142:	learn: 166.7415231	total: 1m 47s	remaining: 10m 42s
# 143:	learn: 166.5701957	total: 1m 47s	remaining: 10m 41s
# 144:	learn: 166.3153371	total: 1m 48s	remaining: 10m 41s
# 145:	learn: 166.2280308	total: 1m 49s	remaining: 10m 39s
# 146:	learn: 166.0151226	total: 1m 50s	remaining: 10m 39s
# 147:	learn: 165.8663313	total: 1m 51s	remaining: 10m 39s
# 148:	learn: 165.6899743	total: 1m 51s	remaining: 10m 38s
# 149:	learn: 165.5989432	total: 1m 52s	remaining: 10m 38s
# 150:	learn: 165.5255938	total: 1m 53s	remaining: 10m 37s
# 151:	learn: 165.3891809	total: 1m 54s	remaining: 10m 37s
# 152:	learn: 165.3071023	total: 1m 54s	remaining: 10m 36s
# 153:	learn: 165.1679015	total: 1m 55s	remaining: 10m 35s
# 154:	learn: 164.9346333	total: 1m 56s	remaining: 10m 34s
# 155:	learn: 164.7890326	total: 1m 57s	remaining: 10m 34s
# 156:	learn: 164.5986251	total: 1m 57s	remaining: 10m 33s
# 157:	learn: 164.4599718	total: 1m 58s	remaining: 10m 33s
# 158:	learn: 164.4040115	total: 1m 59s	remaining: 10m 32s
# 159:	learn: 164.1850586	total: 2m	remaining: 10m 31s
# 160:	learn: 164.1814661	total: 2m 1s	remaining: 10m 30s
# 161:	learn: 164.0404362	total: 2m 1s	remaining: 10m 30s
# 162:	learn: 163.9036403	total: 2m 2s	remaining: 10m 30s
# 163:	learn: 163.8461064	total: 2m 3s	remaining: 10m 29s
# 164:	learn: 163.7796216	total: 2m 4s	remaining: 10m 29s
# 165:	learn: 163.7748962	total: 2m 5s	remaining: 10m 28s

# %%
y_predict = model.predict(X_test)

# %%
#y_pred = np.expm1(y_predict)

# %%
plt.scatter(y_test, y_predict)

# %%
y_pred_s = pd.Series(y_predict)
count, division = np.histogram(y_pred_s)
print(f"Data_Slice: {division}")
print(f"Count: {count}")
y_pred_s.describe()
# Out:
# Data_Slice: [ -64.41751983  923.86819241 1912.15390464 2900.43961688 3888.72532912
#  4877.01104136 5865.29675359 6853.58246583 7841.86817807 8830.15389031
#  9818.43960255]
# Count: [13078   523    55    28     6     3     2     1     0     1]
# count    13697.000000
# mean       261.827579
# std        375.830575
# min        -64.417520
# 25%         62.278950
# 50%        135.445859
# 75%        326.814463
# max       9818.439603
# dtype: float64

# %%
y_pred_less_than_0 = y_pred_s[y_pred_s < 0]
print(y_pred_less_than_0.values)
# Out:
# [-64.41751983  -0.99836991  -0.73712453  -3.38367262  -5.92593878
#   -4.50650317  -4.30371298  -4.55102672  -7.62652669  -7.47675396]

# %%
# negative requirement doesn't mean anything.
y_predict[y_predict < 0] = 0

# %%
plt.scatter(y_test, y_predict)

# %%
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error( y_test, y_predict ))
# Out:
# 0.4859365998182292

# %%
import joblib
filename = 'model1_497029.sav'
joblib.dump(model, filename)
# Out:
# ['model1_497029.sav']

# %%
0.4859365998182292
