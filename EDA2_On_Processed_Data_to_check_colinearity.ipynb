# %%
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df_train = pd.read_csv('input/train_processed.csv')

# %%
df_tmp = df_train.drop(['Unnamed: 0','id','center_id', 'meal_id',
       'city_code', 'region_code', 'city_region',
       'center_type', 'category', 'cuisine',
        'city_code', 'region_code', 'city_code_encoded', 'region_code_encoded',
         'checkout_price','num_orders_log1p','discount'], axis=1)

# %%
df_tmp.columns
# Out:
# Index(['week', 'base_price', 'emailer_for_promotion', 'homepage_featured',
#        'num_orders', 'op_area', 'rate_of_discount', 'week_sin', 'week_cos',
#        'center_id_encoded', 'meal_id_encoded', 'city_region_encoded',
#        'center_type_encoded', 'category_encoded', 'cuisine_encoded', 'Quarter',
#        'Year'],
#       dtype='object')

# %%
df_tmp_vif = df_tmp._get_numeric_data()

# %%
cat_cols = ['week','meal_id_encoded',
                     'center_id_encoded',
                     'emailer_for_promotion',
                     'homepage_featured',
                     'city_region_encoded',
                     'center_type_encoded',
                     'category_encoded',
                     'cuisine_encoded',
                    'Quarter',
                    'Year'
                    ]

# %% [markdown]
# ## __VIF__

# %%
numerical_columns = [col for col in df_tmp_vif.columns if col not in cat_cols]
df_tmp_vif = df_tmp_vif[numerical_columns]
df_tmp_vif
# Out:
#         base_price  num_orders  op_area  rate_of_discount  week_sin  week_cos
# 0           152.29         177      2.0          0.101517  0.120208  0.992749
# 1           152.29         323      2.0          0.108083  0.238672  0.971100
# 2           133.92          96      2.0          0.007467  0.353675  0.935368
# 3           134.86         163      2.0         -0.007415  0.463549  0.886071
# 4           147.50         215      2.0          0.006780  0.566700  0.823924
# ...            ...         ...      ...               ...       ...       ...
# 456541      630.53          13      4.5          0.075333 -0.958705 -0.284404
# 456542      582.03          42      4.5          0.001718 -0.985940 -0.167098
# 456543      581.03          40      4.5         -0.003442 -0.998877 -0.047369
# 456544      581.03          53      4.5         -0.001721 -0.997328  0.073048
# 456545      582.03          27      4.5          0.001718 -0.981316  0.192405
#
# [456546 rows x 6 columns]

# %%
df_tmp_vif.loc[df_tmp_vif.rate_of_discount == 0, 'rate_of_discount'] = 0.000001
#df_tmp.loc[df_tmp.discount == 0, 'discount'] = 0.000001

# %%
y = df_tmp_vif['num_orders']
X = df_tmp_vif.drop('num_orders', axis=1)

# %%
variance_inflation_factor(X.values, 2)
# Out:
# 1.2568806024687715

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif
# Out:
#    VIF Factor          features
# 0    4.590092        base_price
# 1    4.537343           op_area
# 2    1.256881  rate_of_discount
# 3    1.005448          week_sin
# 4    1.011712          week_cos

# %% [markdown]
# ## __ChiSq and Cramer's V test__

# %%
df_tmp_chi = df_tmp[cat_cols]
df_tmp_chi.head()
# Out:
#    week  meal_id_encoded  center_id_encoded  emailer_for_promotion  \
# 0     1               22                 23                      0
# 1     2               22                 23                      0
# 2     3               22                 23                      0
# 3     4               22                 23                      0
# 4     5               22                 23                      0
#
#    homepage_featured  city_region_encoded  center_type_encoded  \
# 0                  0                   30                    2
# 1                  0                   30                    2
# 2                  0                   30                    2
# 3                  0                   30                    2
# 4                  0                   30                    2
#
#    category_encoded  cuisine_encoded Quarter Year
# 0                 0                3      Q1   Y1
# 1                 0                3      Q1   Y1
# 2                 0                3      Q1   Y1
# 3                 0                3      Q1   Y1
# 4                 0                3      Q1   Y1

# %%
import researchpy as rp
import scipy.stats as stats

# %%
crosstab = pd.crosstab(df_tmp_chi['category_encoded'],df_tmp_chi['cuisine_encoded'])

# %%
stats.chi2_contingency(crosstab)
# Out:
# (984756.3995761818,
#  0.0,
#  39,
#  array([[28795.46102693, 31544.88901447, 34434.37955869, 33115.27039992],
#         [ 4641.40772233,  5084.57535495,  5550.3190259 ,  5337.69789682],
#         [ 6595.77946143,  7225.55304394,  7887.40882627,  7585.25866835],
#         [ 3053.59326333,  3345.15431085,  3651.56818809,  3511.68423773],
#         [ 2293.68489703,  2512.68890758,  2742.84951571,  2637.77667968],
#         [ 6614.91789436,  7246.51883928,  7910.29507432,  7607.26819203],
#         [ 6235.5266063 ,  6830.90277869,  7456.60886307,  7170.96175194],
#         [ 7461.28694589,  8173.70030621,  8922.40573787,  8580.60701003],
#         [ 7521.62929913,  8239.80422564,  8994.5647317 ,  8650.00174353],
#         [ 6430.28830611,  7044.26057834,  7689.51009318,  7394.94102237],
#         [ 7495.73612517,  8211.43873783,  8963.60098435,  8620.22415266],
#         [ 6060.35365549,  6639.00408721,  7247.13238096,  6969.50987633],
#         [ 2853.87808676,  3126.37007005,  3412.74345849,  3282.0083847 ],
#         [ 6741.45670973,  7385.13974495,  8061.61356139,  7752.78998392]]))

# %%
table, results = rp.crosstab(df_tmp_chi['category_encoded'],df_tmp_chi['cuisine_encoded'], prop ='col', test = 'chi-square')

# %%
results
# Out:
#                  Chi-square test      results
# 0  Pearson Chi-square ( 39.0) =   984756.3996
# 1                     p-value =        0.0000
# 2                  Cramer's V =        0.8479

# %%
for col_i in df_tmp_chi.columns:
    df_tmp_ = df_tmp_chi.drop([col_i], axis=1)
    #list_of_cols = cat_cols.remove(col_i)
    for col_j in df_tmp_.columns:
        table, results = rp.crosstab(df_tmp_chi[col_i],
                                     df_tmp_chi[col_j], 
                                     prop ='col', test = 'chi-square')
        print('Results for '+col_i+' vs '+col_j+' : ')
        print(results)
# Out:
# Results for week vs meal_id_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 7200.0) =   13793.5614
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0246
# Results for week vs center_id_encoded :
#                     Chi-square test    results
# 0  Pearson Chi-square ( 10944.0) =   1834.8490
# 1                        p-value =      1.0000
# 2                     Cramer's V =      0.0073
# Results for week vs emailer_for_promotion :
#                   Chi-square test     results
# 0  Pearson Chi-square ( 144.0) =   13559.4209
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.1723
# Results for week vs homepage_featured :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 144.0) =   4180.4930
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0957
# Results for week vs city_region_encoded :
#                    Chi-square test   results
# 0  Pearson Chi-square ( 7200.0) =   970.5388
# 1                       p-value =     1.0000
# 2                    Cramer's V =     0.0065
# Results for week vs center_type_encoded :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 288.0) =   102.4283
# 1                      p-value =     1.0000
# 2                   Cramer's V =     0.0106
# Results for week vs category_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 1872.0) =   12042.6264
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0450
# Results for week vs cuisine_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 432.0) =   1100.4505
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0283
# Results for week vs Quarter :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 432.0) =   1369638.0
# 1                      p-value =         0.0
# 2                   Cramer's V =         1.0
# Results for week vs Year :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 288.0) =   913092.0
# 1                      p-value =        0.0
# 2                   Cramer's V =        1.0
# Results for meal_id_encoded vs week :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 7200.0) =   13793.5614
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0246
# Results for meal_id_encoded vs center_id_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 3800.0) =   46953.4512
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0454
# Results for meal_id_encoded vs emailer_for_promotion :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 50.0) =   34104.8150
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.2733
# Results for meal_id_encoded vs homepage_featured :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 50.0) =   26471.6595
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.2408
# Results for meal_id_encoded vs city_region_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 2500.0) =   38606.3744
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0411
# Results for meal_id_encoded vs center_type_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 100.0) =   3989.0765
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0661
# Results for meal_id_encoded vs category_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 650.0) =   5935098.0
# 1                      p-value =         0.0
# 2                   Cramer's V =         1.0
# Results for meal_id_encoded vs cuisine_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   1369638.0
# 1                      p-value =         0.0
# 2                   Cramer's V =         1.0
# Results for meal_id_encoded vs Quarter :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   1242.2150
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0301
# Results for meal_id_encoded vs Year :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 100.0) =   7618.3335
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0913
# Results for center_id_encoded vs week :
#                     Chi-square test    results
# 0  Pearson Chi-square ( 10944.0) =   1834.8490
# 1                        p-value =      1.0000
# 2                     Cramer's V =      0.0073
# Results for center_id_encoded vs meal_id_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 3800.0) =   46953.4512
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0454
# Results for center_id_encoded vs emailer_for_promotion :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 76.0) =   1003.6928
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0469
# Results for center_id_encoded vs homepage_featured :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 76.0) =   3517.6947
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0878
# Results for center_id_encoded vs city_region_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 3800.0) =   22827300.0
# 1                       p-value =          0.0
# 2                    Cramer's V =          1.0
# Results for center_id_encoded vs center_type_encoded :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 152.0) =   913092.0
# 1                      p-value =        0.0
# 2                   Cramer's V =        1.0
# Results for center_id_encoded vs category_encoded :
#                   Chi-square test     results
# 0  Pearson Chi-square ( 988.0) =   39966.1198
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.0821
# Results for center_id_encoded vs cuisine_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 228.0) =   7275.7923
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0729
# Results for center_id_encoded vs Quarter :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 228.0) =   113.7580
# 1                      p-value =     1.0000
# 2                   Cramer's V =     0.0091
# Results for center_id_encoded vs Year :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 152.0) =   559.7826
# 1                      p-value =     0.0000
# 2                   Cramer's V =     0.0248
# Results for emailer_for_promotion vs week :
#                   Chi-square test     results
# 0  Pearson Chi-square ( 144.0) =   13559.4209
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.1723
# Results for emailer_for_promotion vs meal_id_encoded :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 50.0) =   34104.8150
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.2733
# Results for emailer_for_promotion vs center_id_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 76.0) =   1003.6928
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0469
# Results for emailer_for_promotion vs homepage_featured :
#                 Chi-square test     results
# 0  Pearson Chi-square ( 1.0) =   69621.7795
# 1                    p-value =       0.0000
# 2               Cramer's phi =       0.3905
# Results for emailer_for_promotion vs city_region_encoded :
#                  Chi-square test   results
# 0  Pearson Chi-square ( 50.0) =   921.2858
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0449
# Results for emailer_for_promotion vs center_type_encoded :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =   37.5237
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0091
# Results for emailer_for_promotion vs category_encoded :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 13.0) =   31444.5013
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.2624
# Results for emailer_for_promotion vs cuisine_encoded :
#                 Chi-square test     results
# 0  Pearson Chi-square ( 3.0) =   15370.1465
# 1                    p-value =       0.0000
# 2                 Cramer's V =       0.1835
# Results for emailer_for_promotion vs Quarter :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 3.0) =   360.6461
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0281
# Results for emailer_for_promotion vs Year :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =   13.0686
# 1                    p-value =    0.0015
# 2                 Cramer's V =    0.0054
# Results for homepage_featured vs week :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 144.0) =   4180.4930
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0957
# Results for homepage_featured vs meal_id_encoded :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 50.0) =   26471.6595
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.2408
# Results for homepage_featured vs center_id_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 76.0) =   3517.6947
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0878
# Results for homepage_featured vs emailer_for_promotion :
#                 Chi-square test     results
# 0  Pearson Chi-square ( 1.0) =   69621.7795
# 1                    p-value =       0.0000
# 2               Cramer's phi =       0.3905
# Results for homepage_featured vs city_region_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 50.0) =   1922.8746
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0649
# Results for homepage_featured vs center_type_encoded :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 2.0) =   447.2018
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0313
# Results for homepage_featured vs category_encoded :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 13.0) =   12232.9433
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.1637
# Results for homepage_featured vs cuisine_encoded :
#                 Chi-square test    results
# 0  Pearson Chi-square ( 3.0) =   4401.0744
# 1                    p-value =      0.0000
# 2                 Cramer's V =      0.0982
# Results for homepage_featured vs Quarter :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 3.0) =   904.7499
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0445
# Results for homepage_featured vs Year :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 2.0) =   222.2167
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0221
# Results for city_region_encoded vs week :
#                    Chi-square test   results
# 0  Pearson Chi-square ( 7200.0) =   970.5388
# 1                       p-value =     1.0000
# 2                    Cramer's V =     0.0065
# Results for city_region_encoded vs meal_id_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 2500.0) =   38606.3744
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0411
# Results for city_region_encoded vs center_id_encoded :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 3800.0) =   22827300.0
# 1                       p-value =          0.0
# 2                    Cramer's V =          1.0
# Results for city_region_encoded vs emailer_for_promotion :
#                  Chi-square test   results
# 0  Pearson Chi-square ( 50.0) =   921.2858
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0449
# Results for city_region_encoded vs homepage_featured :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 50.0) =   1922.8746
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0649
# Results for city_region_encoded vs center_type_encoded :
#                   Chi-square test      results
# 0  Pearson Chi-square ( 100.0) =   532540.4372
# 1                      p-value =        0.0000
# 2                   Cramer's V =        0.7637
# Results for city_region_encoded vs category_encoded :
#                   Chi-square test     results
# 0  Pearson Chi-square ( 650.0) =   34121.8618
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.0758
# Results for city_region_encoded vs cuisine_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   6279.5458
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0677
# Results for city_region_encoded vs Quarter :
#                   Chi-square test  results
# 0  Pearson Chi-square ( 150.0) =   62.6422
# 1                      p-value =    1.0000
# 2                   Cramer's V =    0.0068
# Results for city_region_encoded vs Year :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 100.0) =   244.3043
# 1                      p-value =     0.0000
# 2                   Cramer's V =     0.0164
# Results for center_type_encoded vs week :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 288.0) =   102.4283
# 1                      p-value =     1.0000
# 2                   Cramer's V =     0.0106
# Results for center_type_encoded vs meal_id_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 100.0) =   3989.0765
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0661
# Results for center_type_encoded vs center_id_encoded :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 152.0) =   913092.0
# 1                      p-value =        0.0
# 2                   Cramer's V =        1.0
# Results for center_type_encoded vs emailer_for_promotion :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =   37.5237
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0091
# Results for center_type_encoded vs homepage_featured :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 2.0) =   447.2018
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0313
# Results for center_type_encoded vs city_region_encoded :
#                   Chi-square test      results
# 0  Pearson Chi-square ( 100.0) =   532540.4372
# 1                      p-value =        0.0000
# 2                   Cramer's V =        0.7637
# Results for center_type_encoded vs category_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 26.0) =   3363.9994
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0607
# Results for center_type_encoded vs cuisine_encoded :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 6.0) =   383.6623
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0205
# Results for center_type_encoded vs Quarter :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 6.0) =    1.8480
# 1                    p-value =    0.9331
# 2                 Cramer's V =    0.0014
# Results for center_type_encoded vs Year :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =   45.2932
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0070
# Results for category_encoded vs week :
#                    Chi-square test     results
# 0  Pearson Chi-square ( 1872.0) =   12042.6264
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.0450
# Results for category_encoded vs meal_id_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 650.0) =   5935098.0
# 1                      p-value =         0.0
# 2                   Cramer's V =         1.0
# Results for category_encoded vs center_id_encoded :
#                   Chi-square test     results
# 0  Pearson Chi-square ( 988.0) =   39966.1198
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.0821
# Results for category_encoded vs emailer_for_promotion :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 13.0) =   31444.5013
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.2624
# Results for category_encoded vs homepage_featured :
#                  Chi-square test     results
# 0  Pearson Chi-square ( 13.0) =   12232.9433
# 1                     p-value =       0.0000
# 2                  Cramer's V =       0.1637
# Results for category_encoded vs city_region_encoded :
#                   Chi-square test     results
# 0  Pearson Chi-square ( 650.0) =   34121.8618
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.0758
# Results for category_encoded vs center_type_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 26.0) =   3363.9994
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0607
# Results for category_encoded vs cuisine_encoded :
#                  Chi-square test      results
# 0  Pearson Chi-square ( 39.0) =   984756.3996
# 1                     p-value =        0.0000
# 2                  Cramer's V =        0.8479
# Results for category_encoded vs Quarter :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 39.0) =   1126.9134
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0287
# Results for category_encoded vs Year :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 26.0) =   7220.7536
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0889
# Results for cuisine_encoded vs week :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 432.0) =   1100.4505
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0283
# Results for cuisine_encoded vs meal_id_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   1369638.0
# 1                      p-value =         0.0
# 2                   Cramer's V =         1.0
# Results for cuisine_encoded vs center_id_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 228.0) =   7275.7923
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0729
# Results for cuisine_encoded vs emailer_for_promotion :
#                 Chi-square test     results
# 0  Pearson Chi-square ( 3.0) =   15370.1465
# 1                    p-value =       0.0000
# 2                 Cramer's V =       0.1835
# Results for cuisine_encoded vs homepage_featured :
#                 Chi-square test    results
# 0  Pearson Chi-square ( 3.0) =   4401.0744
# 1                    p-value =      0.0000
# 2                 Cramer's V =      0.0982
# Results for cuisine_encoded vs city_region_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   6279.5458
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0677
# Results for cuisine_encoded vs center_type_encoded :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 6.0) =   383.6623
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0205
# Results for cuisine_encoded vs category_encoded :
#                  Chi-square test      results
# 0  Pearson Chi-square ( 39.0) =   984756.3996
# 1                     p-value =        0.0000
# 2                  Cramer's V =        0.8479
# Results for cuisine_encoded vs Quarter :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 9.0) =   130.4984
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0098
# Results for cuisine_encoded vs Year :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 6.0) =   359.4152
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0198
# Results for Quarter vs week :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 432.0) =   1369638.0
# 1                      p-value =         0.0
# 2                   Cramer's V =         1.0
# Results for Quarter vs meal_id_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   1242.2150
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0301
# Results for Quarter vs center_id_encoded :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 228.0) =   113.7580
# 1                      p-value =     1.0000
# 2                   Cramer's V =     0.0091
# Results for Quarter vs emailer_for_promotion :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 3.0) =   360.6461
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0281
# Results for Quarter vs homepage_featured :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 3.0) =   904.7499
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0445
# Results for Quarter vs city_region_encoded :
#                   Chi-square test  results
# 0  Pearson Chi-square ( 150.0) =   62.6422
# 1                      p-value =    1.0000
# 2                   Cramer's V =    0.0068
# Results for Quarter vs center_type_encoded :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 6.0) =    1.8480
# 1                    p-value =    0.9331
# 2                 Cramer's V =    0.0014
# Results for Quarter vs category_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 39.0) =   1126.9134
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0287
# Results for Quarter vs cuisine_encoded :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 9.0) =   130.4984
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0098
# Results for Quarter vs Year :
#                 Chi-square test     results
# 0  Pearson Chi-square ( 6.0) =   21089.8334
# 1                    p-value =       0.0000
# 2                 Cramer's V =       0.1520
# Results for Year vs week :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 288.0) =   913092.0
# 1                      p-value =        0.0
# 2                   Cramer's V =        1.0
# Results for Year vs meal_id_encoded :
#                   Chi-square test    results
# 0  Pearson Chi-square ( 100.0) =   7618.3335
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0913
# Results for Year vs center_id_encoded :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 152.0) =   559.7826
# 1                      p-value =     0.0000
# 2                   Cramer's V =     0.0248
# Results for Year vs emailer_for_promotion :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =   13.0686
# 1                    p-value =    0.0015
# 2                 Cramer's V =    0.0054
# Results for Year vs homepage_featured :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 2.0) =   222.2167
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0221
# Results for Year vs city_region_encoded :
#                   Chi-square test   results
# 0  Pearson Chi-square ( 100.0) =   244.3043
# 1                      p-value =     0.0000
# 2                   Cramer's V =     0.0164
# Results for Year vs center_type_encoded :
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =   45.2932
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0070
# Results for Year vs category_encoded :
#                  Chi-square test    results
# 0  Pearson Chi-square ( 26.0) =   7220.7536
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0889
# Results for Year vs cuisine_encoded :
#                 Chi-square test   results
# 0  Pearson Chi-square ( 6.0) =   359.4152
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.0198
# Results for Year vs Quarter :
#                 Chi-square test     results
# 0  Pearson Chi-square ( 6.0) =   21089.8334
# 1                    p-value =       0.0000
# 2                 Cramer's V =       0.1520
